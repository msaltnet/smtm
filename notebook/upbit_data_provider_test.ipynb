# %%
import os
os.chdir('../')

# %% [markdown]
# ### 현재 디렉토리가 smtm 프로젝트 root로 설정되었는지 확인
# 분석 결과 파일이 저장될 output 폴더 생성

# %%
print("현재 디렉토리 " , os.getcwd())
# Out:
# 현재 디렉토리  C:\01_Code\smtm

# %%
from smtm import UpbitDataProvider

# %%
dp = UpbitDataProvider()

# %%
dp.get_info()
# Out:
# {'market': 'KRW-BTC',
#  'date_time': '2021-07-14T23:46:00',
#  'opening_price': 38721000.0,
#  'high_price': 38736000.0,
#  'low_price': 38719000.0,
#  'closing_price': 38719000.0,
#  'acc_price': 53328403.47933,
#  'acc_volume': 1.37727091}
